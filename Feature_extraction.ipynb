# %%
import pandas as pd
import os
import numpy as np
import mediapipe as mp
import cv2

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
def upload(path , new_data):
    #csv_file_path = 'existing_file.csv'
    existing_df = pd.read_csv(path)

    # Create a DataFrame from the new data
    new_df = pd.DataFrame(new_data, columns=existing_df.columns)

    # Concatenate the two DataFrames
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)

    # Save the combined DataFrame back to the CSV file
    combined_df.to_csv(path, index=False)

# %%
img_path = "Gestures/Gesture_1/Gesture_1"
gesture_path_csv = "Gestures/Gesture_1/thumbsup.csv"

with mp_hands.Hands(min_detection_confidence=0.8 , min_tracking_confidence = 0.5) as hands:
#     count=0
    flag=0
    for file in os.listdir(img_path):
        frame = cv2.imread(os.path.join(img_path,file))
#         if flag==0:
#             flag =1
#             continue
        
#         print(frame)
#         print("/////////////////////////////////////////////////////////////////////////")
#         count+=1
#         if count==5:
#             break
        
          
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)
        
        if results.multi_hand_landmarks:
            a=results.multi_hand_landmarks
            xtr = np.array([a[0].landmark[i].x for i in range(21)] +
               [a[0].landmark[i].y for i in range(21)] +
               [a[0].landmark[i].z for i in range(21)] +
                          ["thumbsup"])
#             np.concatenate(xtr,"palm")

            xtr = xtr.flatten()  # Flatten the array to create a 1D array if needed
#             xtr1 = xtr.reshape(21,3)
            
#             xtr1 = np.append(xtr1,["palm"])
#             print(xtr1.shape)
            xtr1 = xtr.reshape(1,64)
            print(xtr1.shape)
            
            if not os.path.exists(gesture_path_csv):
#                 col = np.arange(63).reshape((63,1))
#                 col = np.transpose(col)
#                 df = pd.DataFrame(xtr1, columns=['X', 'Y', 'Z'])
                df = pd.DataFrame(xtr1)
                df.to_csv(gesture_path_csv , index=False)
            else:
                upload(gesture_path_csv , xtr1)
# Out:
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# (1, 64)
# ...
